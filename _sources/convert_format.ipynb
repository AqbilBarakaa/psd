# %%
pip install pydub
# Out:
# Requirement already satisfied: pydub in c:\users\acer\appdata\local\programs\python\python39\lib\site-packages (0.25.1)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from pydub import AudioSegment

folder = r"C:\Semester5\psd\psd\uji\buka"
files = [f for f in os.listdir(folder) if f.endswith(".waptt")]

for idx, fname in enumerate(sorted(files)):
    src_path = os.path.join(folder, fname)
    # dst_path = os.path.join(folder, f"buka_uji_{idx}.wav")
    dst_path = os.path.join(folder, f"buka_uji_5.wav")
    # Konversi ke wav (ganti 'AudioSegment.from_file' jika format .waptt tidak dikenali, misal .mp3, .ogg, dll)
    audio = AudioSegment.from_file(src_path)
    audio.export(dst_path, format="wav")
    print(f"Converted: {src_path} -> {dst_path}")
# Out:
# Converted: C:\Semester5\psd\psd\uji\buka\WhatsApp Audio 2025-11-12 at 15.29.20_1c471a42.waptt -> C:\Semester5\psd\psd\uji\buka\buka_uji_6.wav

# %%
import os
from pydub import AudioSegment

folder = r"C:\Semester5\psd\psd\uji\tutup"
files = [f for f in os.listdir(folder) if f.endswith(".waptt")]

for idx, fname in enumerate(sorted(files)):
    src_path = os.path.join(folder, fname)
    # dst_path = os.path.join(folder, f"tutup_uji_{idx}.wav")
    dst_path = os.path.join(folder, f"tutup_uji_5.wav")
    # Konversi ke wav (ganti 'AudioSegment.from_file' jika format .waptt tidak dikenali, misal .mp3, .ogg, dll)
    audio = AudioSegment.from_file(src_path)
    audio.export(dst_path, format="wav")
    print(f"Converted: {src_path} -> {dst_path}")
# Out:
# Converted: C:\Semester5\psd\psd\uji\tutup\WhatsApp Audio 2025-11-12 at 15.32.21_e2128bf0.waptt -> C:\Semester5\psd\psd\uji\tutup\tutup_uji_5.wav

# %%
import os
from pydub import AudioSegment

# Folder sebelumnya
folder1 = r"C:\Semester5\psd\psd\dataset\aqbil\tutup"
files1 = [f for f in os.listdir(folder1) if f.endswith(".wav") and f.startswith("tutup_")]
start_idx = len(files1)  # Penomoran lanjutan

# Folder baru
folder2 = r"C:\Semester5\psd\psd\dataset\reni\tutup"
files2 = [f for f in os.listdir(folder2) if f.endswith(".waptt")]

for idx, fname in enumerate(sorted(files2)):
    src_path = os.path.join(folder2, fname)
    dst_path = os.path.join(folder2, f"tutup_{start_idx + idx}.wav")
    audio = AudioSegment.from_file(src_path)
    audio.export(dst_path, format="wav")
    print(f"Converted: {src_path} -> {dst_path}")
# Out:
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.16.06_9097f997.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_50.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.16.21_d8943ef5.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_51.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.16.27_725dc94f.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_52.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.16.32_26de54f2.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_53.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.16.35_dfbe75cf.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_54.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.16.43_17b83742.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_55.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.16.49_5dfa7783.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_56.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.16.56_c4917cab.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_57.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.00_5980affc.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_58.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.07_8981c1be.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_59.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.13_dde9115c.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_60.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.15_d17d2984.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_61.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.18_31213b22.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_62.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.22_de02a495.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_63.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.31_d627451a.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_64.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.34_ed796ef8.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_65.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.40_c92f4d7a.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_66.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.43_06124361.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_67.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.52_90727eab.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_68.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.55_4c35b0ef.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_69.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.17.57_78639cac.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_70.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.18.04_69a008fd.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_71.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.18.09_a37fa04c.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_72.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.18.14_58671611.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_73.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.20_aba97a73.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_74.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.22_201c89de.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_75.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.25_061f62ed.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_76.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.27_e456cbca.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_77.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.33_6a549aad.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_78.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.37_5bff6d72.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_79.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.40_e48ccf92.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_80.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.42_04dc876b.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_81.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.43_91a7734a.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_82.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.47_03892b83.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_83.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.49_55872ca5.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_84.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.51_58505905.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_85.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.23.59_e87ace3b.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_86.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.24.00_47c5a133.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_87.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.24.06_95e16ff8.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_88.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.24.15_baefb416.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_89.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.24.25_562e12f5.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_90.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.24.31_b2ecd85e.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_91.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.24.37_7c2a373d.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_92.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.24.44_a695ad5f.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_93.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.24.48_e9b732b5.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_94.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.24.52_9014bcec.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_95.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.25.00_262fccfa.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_96.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.25.00_4b8db990.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_97.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.25.07_be84e5df.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_98.wav
# Converted: C:\Semester5\psd\psd\dataset\reni\tutup\WhatsApp Audio 2025-11-11 at 20.25.31_8b293158.waptt -> C:\Semester5\psd\psd\dataset\reni\tutup\tutup_99.wav
